# %%
import pandas as pd

# %%
binary = pd.read_csv("data/training/training_utterances_binary.csv", sep="~")
bill_start_end_times = pd.read_csv("data/cleaned/bill_start_end_times_longest.csv", sep="~")

# %%
assert(len(binary[binary["transition_value"]==1]) == len(bill_start_end_times))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-38-b94e24f60669> in <module>()
# ----> 1 assert(len(binary[binary["transition_value"]==1]) == len(bill_start_end_times))
#
# AssertionError:

# %%
len(binary[binary["transition_value"]==1])
# Out:
# 6118

# %%
binary
# Out:
#         start  end                                               text  \
# 0           1    7               Please call the roll our anderson no
# 1           7   12                   Nobel by very he'll know block I
# 2          12   18                 can my daily all bipolar no games.
# 3          18   20                                    No, ...only ...
# 4          22   24                                         Know paul.
# 5          24   27                                     By hancock ...
# 6          27   31                ...I ...where ...hilton highway so.
# 7          31   33                                            I half.
# 8          33   34                                       No, jackson.
# 9          40   44                          Lever by loop I'm acquire
# 10         44   50          ...but I mean there's a time it's so high
# 11         50   52                                   ...by more lock.
# ...

# %%
bill_start_end_times
# Out:
#                  bill_id  hearing_id  video_id  speaker_start_time  \
# 0      CA_201520160SB376         542      4161                   1
# 1      CA_201520160SB114         542      4161                  91
# 2      CA_201520160SB660         542      4161                 446
# 3      CA_201520160SB322         542      4161                 991
# 4      CA_201520160SB773         542      4161                1241
# 5      CA_201520160SB313         542      4161                1516
# 6       CA_201520162AB15         539      4221                   0
# 7      CA_201520160AB858         541      4222                   2
# 8      CA_201520160AB390         541      4222                 121
# 9      CA_201520160AB866         541      4222                 124
# 10     CA_201520160AB918         541      4222                 183
# 11     CA_201520160AB920         541      4222                 256
# 12     CA_201520160AB423         541      4222                 314
# ...
