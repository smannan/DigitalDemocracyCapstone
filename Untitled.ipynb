# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

import spacy
import en_core_web_sm

nlp = en_core_web_sm.load()

from nltk.stem import WordNetLemmatizer 

from keras.utils.np_utils import to_categorical
from keras.layers import Embedding, LSTM, Dense, Conv1D, MaxPooling1D, Dropout, Activation
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import ModelCheckpoint

# %%
data_dir = "/Users/brucerowan/Documents/capstone/DigitalDemocracyCapstone/data/training/"
target_col = 'transition_value'
training_output_filename = data_dir  + "training_utterances_binary.csv"

# %%
# split dataset evenly based on labels
def split_test_train(total, stratify_col):
    transition_rows = total[total[stratify_col] != 0]
    non_transition_rows = total[total[stratify_col] == 0]
    
    # first split transitions into training/testing
    X_train1, X_test1, y_train1, y_test1 = train_test_split(transition_rows, 
                                                    transition_rows[target_col], 
                                                    test_size=0.30, random_state=42)
    
    # assert there are only transition labels in this dataframe
    assert len(X_train1[X_train1[target_col] == 0]) == 0
    assert len(X_test1[X_test1[target_col] == 0]) == 0
    
    train_len = len(X_train1) # number of non-transitions to add to training set
    test_len = len(X_test1) # number of non-transitions to add to testing set
    print(train_len)
    
    # next split non-transitions into training/testing
    X_train2, X_test2, y_train2, y_test2 = train_test_split(non_transition_rows, 
                                                    non_transition_rows[target_col], 
                                                    test_size=0.30, random_state=42)
    
    # pick train_len random rows from non-transition training set
    ###change n = train_len
   
    X_train2 = X_train2.sample(n = train_len*3, axis=0)
    
    # pick test_len random rows from non_transitions testing set
    X_test2 = X_test2.sample(n = test_len, axis=0)
    
    # assert there are no transition utterances in non-transition training and testing set
    assert len(X_train2[X_train2[target_col] != 0]) == 0
    assert len(X_test2[X_test2[target_col] != 0]) == 0
    
    # final result, concat the dataframe
    X_train_final = pd.concat([X_train1, X_train2])
    X_test_final = pd.concat([X_test1, X_test2])
    return X_train_final['text'], X_test_final['text'], X_train_final[target_col], X_test_final[target_col]

# %%
train = pd.read_table(training_output_filename, sep="~")[['text', target_col]]
x_train, x_test, y_train, y_test = split_test_train(train, target_col)
# Out:
# 4282

# %% [markdown]
# ## Tokenize and pad word len

# %%
tokenizer = Tokenizer(num_words=40000)
tokenizer.fit_on_texts(x_train)
sequences = tokenizer.texts_to_sequences(x_train)

padded = pad_sequences(sequences, maxlen = 44)

# %%
pred = to_categorical(y_train)

# %% [markdown]
# ## Model

# %%
model = Sequential()
model.add(Embedding(40000, 150, input_length=44))
model.add(Conv1D(64, 5, activation='relu'))
model.add(MaxPooling1D(pool_size=4))
model.add(LSTM(150, dropout=0.2, recurrent_dropout=0.5))
model.add(Dense(2, activation='sigmoid')) #fully connected layer
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(padded, pred,validation_split=0.5, epochs = 50, callbacks = callbacks_list)
# Out:
# Train on 8564 samples, validate on 8564 samples
# Epoch 1/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.6244 - acc: 0.6615Epoch 00001: val_acc improved from -inf to 0.52160, saving model to weights.best.hdf5
# 8564/8564 [==============================] - 43s 5ms/step - loss: 0.6243 - acc: 0.6616 - val_loss: 0.7421 - val_acc: 0.5216
# Epoch 2/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.5390 - acc: 0.7352Epoch 00002: val_acc improved from 0.52160 to 0.57187, saving model to weights.best.hdf5
# 8564/8564 [==============================] - 43s 5ms/step - loss: 0.5392 - acc: 0.7350 - val_loss: 0.7857 - val_acc: 0.5719
# Epoch 3/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.4243 - acc: 0.8104Epoch 00003: val_acc did not improve
# 8564/8564 [==============================] - 38s 4ms/step - loss: 0.4240 - acc: 0.8105 - val_loss: 1.2557 - val_acc: 0.4831
# Epoch 4/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.3106 - acc: 0.8682Epoch 00004: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.3116 - acc: 0.8675 - val_loss: 1.3355 - val_acc: 0.5286
# Epoch 5/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.2320 - acc: 0.9027Epoch 00005: val_acc improved from 0.57187 to 0.64444, saving model to weights.best.hdf5
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.2320 - acc: 0.9026 - val_loss: 1.1390 - val_acc: 0.6444
# Epoch 6/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1889 - acc: 0.9209Epoch 00006: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.1888 - acc: 0.9209 - val_loss: 1.3086 - val_acc: 0.5859
# Epoch 7/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1586 - acc: 0.9336Epoch 00007: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.1588 - acc: 0.9334 - val_loss: 1.7297 - val_acc: 0.5431
# Epoch 8/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1446 - acc: 0.9393Epoch 00008: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.1447 - acc: 0.9392 - val_loss: 1.6150 - val_acc: 0.6212
# Epoch 9/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1330 - acc: 0.9449Epoch 00009: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.1329 - acc: 0.9449 - val_loss: 1.8804 - val_acc: 0.5795
# Epoch 10/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1255 - acc: 0.9458Epoch 00010: val_acc did not improve
# 8564/8564 [==============================] - 48s 6ms/step - loss: 0.1253 - acc: 0.9458 - val_loss: 2.7850 - val_acc: 0.4809
# Epoch 11/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1143 - acc: 0.9513Epoch 00011: val_acc did not improve
# 8564/8564 [==============================] - 46s 5ms/step - loss: 0.1144 - acc: 0.9514 - val_loss: 3.3972 - val_acc: 0.4568
# Epoch 12/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1133 - acc: 0.9519Epoch 00012: val_acc did not improve
# 8564/8564 [==============================] - 43s 5ms/step - loss: 0.1137 - acc: 0.9517 - val_loss: 2.3035 - val_acc: 0.5357
# Epoch 13/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1101 - acc: 0.9529Epoch 00013: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.1102 - acc: 0.9529 - val_loss: 2.5011 - val_acc: 0.5390
# Epoch 14/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1056 - acc: 0.9558Epoch 00014: val_acc did not improve
# 8564/8564 [==============================] - 43s 5ms/step - loss: 0.1058 - acc: 0.9555 - val_loss: 2.3356 - val_acc: 0.5559
# Epoch 15/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1026 - acc: 0.9562Epoch 00015: val_acc did not improve
# 8564/8564 [==============================] - 38s 4ms/step - loss: 0.1027 - acc: 0.9560 - val_loss: 2.9899 - val_acc: 0.4969
# Epoch 16/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.1007 - acc: 0.9566Epoch 00016: val_acc did not improve
# 8564/8564 [==============================] - 38s 4ms/step - loss: 0.1009 - acc: 0.9564 - val_loss: 2.1350 - val_acc: 0.5685
# Epoch 17/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0968 - acc: 0.9586Epoch 00017: val_acc did not improve
# 8564/8564 [==============================] - 38s 4ms/step - loss: 0.0967 - acc: 0.9587 - val_loss: 2.1225 - val_acc: 0.5929
# Epoch 18/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0944 - acc: 0.9590Epoch 00018: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0943 - acc: 0.9590 - val_loss: 2.1703 - val_acc: 0.5706
# Epoch 19/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0928 - acc: 0.9598Epoch 00019: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0931 - acc: 0.9597 - val_loss: 3.1922 - val_acc: 0.4689
# Epoch 20/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0919 - acc: 0.9613Epoch 00020: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0918 - acc: 0.9612 - val_loss: 2.8126 - val_acc: 0.4776
# Epoch 21/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0926 - acc: 0.9591Epoch 00021: val_acc did not improve
# 8564/8564 [==============================] - 43s 5ms/step - loss: 0.0924 - acc: 0.9592 - val_loss: 2.6713 - val_acc: 0.5202
# Epoch 22/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0903 - acc: 0.9609Epoch 00022: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0901 - acc: 0.9610 - val_loss: 2.4145 - val_acc: 0.5455
# Epoch 23/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0881 - acc: 0.9621Epoch 00023: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0881 - acc: 0.9621 - val_loss: 3.0007 - val_acc: 0.5333
# Epoch 24/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0885 - acc: 0.9611Epoch 00024: val_acc did not improve
# 8564/8564 [==============================] - 43s 5ms/step - loss: 0.0884 - acc: 0.9611 - val_loss: 2.9151 - val_acc: 0.5437
# Epoch 25/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0867 - acc: 0.9627Epoch 00025: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0867 - acc: 0.9627 - val_loss: 2.3536 - val_acc: 0.6081
# Epoch 26/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0857 - acc: 0.9627Epoch 00026: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0861 - acc: 0.9625 - val_loss: 3.2555 - val_acc: 0.4551
# Epoch 27/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0847 - acc: 0.9641Epoch 00027: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0847 - acc: 0.9640 - val_loss: 2.8817 - val_acc: 0.5373
# Epoch 28/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0848 - acc: 0.9636Epoch 00028: val_acc did not improve
# 8564/8564 [==============================] - 40s 5ms/step - loss: 0.0846 - acc: 0.9637 - val_loss: 3.2114 - val_acc: 0.5110
# Epoch 29/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0834 - acc: 0.9643Epoch 00029: val_acc did not improve
# 8564/8564 [==============================] - 39s 5ms/step - loss: 0.0835 - acc: 0.9643 - val_loss: 3.2581 - val_acc: 0.5217
# Epoch 30/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0841 - acc: 0.9638Epoch 00030: val_acc did not improve
# 8564/8564 [==============================] - 39s 5ms/step - loss: 0.0841 - acc: 0.9637 - val_loss: 2.3608 - val_acc: 0.5977
# Epoch 31/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0817 - acc: 0.9636Epoch 00031: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0816 - acc: 0.9637 - val_loss: 3.2046 - val_acc: 0.5098
# Epoch 32/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0795 - acc: 0.9644Epoch 00032: val_acc did not improve
# 8564/8564 [==============================] - 40s 5ms/step - loss: 0.0798 - acc: 0.9643 - val_loss: 3.4362 - val_acc: 0.4695
# Epoch 33/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0819 - acc: 0.9656Epoch 00033: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0818 - acc: 0.9657 - val_loss: 3.0141 - val_acc: 0.5313
# Epoch 34/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0827 - acc: 0.9650Epoch 00034: val_acc did not improve
# 8564/8564 [==============================] - 46s 5ms/step - loss: 0.0827 - acc: 0.9650 - val_loss: 2.6786 - val_acc: 0.5503
# Epoch 35/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0785 - acc: 0.9630Epoch 00035: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0786 - acc: 0.9629 - val_loss: 2.9203 - val_acc: 0.5567
# Epoch 36/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0794 - acc: 0.9645Epoch 00036: val_acc did not improve
# 8564/8564 [==============================] - 39s 5ms/step - loss: 0.0795 - acc: 0.9644 - val_loss: 2.7411 - val_acc: 0.5721
# Epoch 37/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0803 - acc: 0.9646Epoch 00037: val_acc did not improve
# 8564/8564 [==============================] - 40s 5ms/step - loss: 0.0803 - acc: 0.9647 - val_loss: 3.3255 - val_acc: 0.4975
# Epoch 38/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0789 - acc: 0.9652Epoch 00038: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0789 - acc: 0.9651 - val_loss: 2.4117 - val_acc: 0.5945
# Epoch 39/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0782 - acc: 0.9634Epoch 00039: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0783 - acc: 0.9633 - val_loss: 3.5924 - val_acc: 0.5009
# Epoch 40/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0774 - acc: 0.9655Epoch 00040: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0776 - acc: 0.9654 - val_loss: 3.8519 - val_acc: 0.4921
# Epoch 41/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0777 - acc: 0.9656Epoch 00041: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0780 - acc: 0.9653 - val_loss: 3.7506 - val_acc: 0.4830
# Epoch 42/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0788 - acc: 0.9659Epoch 00042: val_acc did not improve
# 8564/8564 [==============================] - 42s 5ms/step - loss: 0.0790 - acc: 0.9656 - val_loss: 3.3418 - val_acc: 0.5228
# Epoch 43/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0768 - acc: 0.9656Epoch 00043: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0768 - acc: 0.9656 - val_loss: 3.2597 - val_acc: 0.5290
# Epoch 44/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0777 - acc: 0.9657Epoch 00044: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0781 - acc: 0.9654 - val_loss: 3.0836 - val_acc: 0.4992
# Epoch 45/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0786 - acc: 0.9647Epoch 00045: val_acc did not improve
# 8564/8564 [==============================] - 43s 5ms/step - loss: 0.0784 - acc: 0.9648 - val_loss: 3.3645 - val_acc: 0.5109
# Epoch 46/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0790 - acc: 0.9648Epoch 00046: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0790 - acc: 0.9649 - val_loss: 3.7331 - val_acc: 0.4975
# Epoch 47/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0769 - acc: 0.9643Epoch 00047: val_acc did not improve
# 8564/8564 [==============================] - 53s 6ms/step - loss: 0.0770 - acc: 0.9643 - val_loss: 3.9215 - val_acc: 0.4825
# Epoch 48/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0773 - acc: 0.9661Epoch 00048: val_acc did not improve
# 8564/8564 [==============================] - 41s 5ms/step - loss: 0.0775 - acc: 0.9661 - val_loss: 3.3273 - val_acc: 0.5497
# Epoch 49/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0786 - acc: 0.9656Epoch 00049: val_acc did not improve
# 8564/8564 [==============================] - 40s 5ms/step - loss: 0.0784 - acc: 0.9657 - val_loss: 4.4761 - val_acc: 0.4333
# Epoch 50/50
# 8544/8564 [============================>.] - ETA: 0s - loss: 0.0786 - acc: 0.9646Epoch 00050: val_acc did not improve
# 8564/8564 [==============================] - 39s 5ms/step - loss: 0.0786 - acc: 0.9646 - val_loss: 3.3842 - val_acc: 0.5200

# %% [markdown]
# ## testing

# %%
sequences = tokenizer.texts_to_sequences(x_test)
test_padded = pad_sequences(sequences, maxlen = 44)
print(test_padded.shape)
# Out:
# (3672, 44)

# %%
model.load_weights("weights.best.hdf5")
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])


predictions = model.predict(test_padded)
predictions = np.argmax(predictions, axis =1)
accuracy_score(predictions,y_test)
# Out:
# 0.5403050108932462

# %%
wrong = 0
missed_transition = 0
for i in range(len(predictions)):
    if predictions[i] != y_test.iloc[i]:
        wrong= wrong+1
        print(predictions[i],y_test.iloc[i],x_test.iloc[i])
        if predictions[i] == 0:
            missed_transition = missed_transition +1
# Out:
# 0 1 okay, we're going to to bring geo to order as a sub committee.
# 0 1 second, 1160 reduces barriers to injured workers seeking physical and occupational therapy.
# 0 1 members, we will now take up <BILL_ID> hill without reference to file, the clerk will read.
# 0 1 and it's important that i note this that each year there are <BILL_ID> children
# 0 1 thank you very much madam chair and members.
# 0 1 that's that's a really important component in doing this.
# 0 1 this committee to order.
# 0 1 item 9, <BILL_ID> by runner.
# 0 1 were either born in or spent years in these camps during world war ii and shortly after world war ii.
# 0 1 aye. >> aye, de leon, fuller.
# 0 1 we also think that it really will help in hands public trust by insuring that the information that
# 0 1 they are csu eu employees that are running our common management system.
# 0 1 aye, lara.
# 0 1 public schools, asian lunar, new year day.
# 0 1 there he is.
# 0 1 we want to hear how people cast their votes, so that's important, right?
# 0 1 and e-cigarette companies have been able to pander
# 0 1 thank you very much.
# 0 1 mr. chairman, members of the committee, craig deluz with the firearms policy coalition.
# 0 1 ...jammed the wong
# 0 1 they are successfully able to transition to stable housing when we match them with housing and match them with services.
# 0 1 do pass with amendments, environmental quality.
# 0 1 a role.
# 0 1 thank you madame chair and colleagues.
# 0 1 thank you.
# 0 1 aye. hill? aye.
# 0 1 all right, thank you.
# 0 1 ms brown, if you keep it brief.
# 0 1 think
# 0 1 particularly around construction contracts when you,
# 0 1 53.
# 0 1 going to pair all right.
# 0 1 okay, very good.
# 0 1 we'll call mr. ridley-thomas and we'll give the, we'll give it to miss campos over there so for the second.
# 0 1 kyle johnson, sierra club california supports of building advanced stormwater capture, which we all need.
# 0 1 this hearing of the senate committee on public employment retirement.
# 0 1 members, is there any objection to using the unanimous roll call?
# 0 1 the time of station which with a
# 0 1 good morning, amanda wilcox on behalf of the 27 california chapters of the brady campaign to prevent gun violence.
# 0 1 multiple systems at a cheaper rate than would be paid for each individual system.
# 0 1 this does not translate into the long-term employment in california.
# 0 1 and ...those who follow us ...every child of the mother earth.
# 0 1 you'll find those on page 5, line 16 of the bill itself.
# 0 1 aye. >> aye, lara, leno, leyva.
# 0 1 to help students better understand those with autism and special needs.
# 0 1 mr. ting, you are recognized.
# 0 1 file item 96 <BILL_ID> mullin, the clerk will read.
# 0 1 but this could have saved a lot of time and money.
# 0 1 on behalf of fresno county and i'm here in support because there's a lot of asthma amongst adults and
# 0 1 during that time i had a genesis loan,
# 0 1 mr. houston's
# 0 1 one out of four of california's children living in poverty.
# 0 1 thank you, mr. rodriguez.
# 0 1 please join me in recognizing april 2016 as donate life california dmv month.
# 0 1 item in regular business, and that's <BILL_ID>
# 0 1 complementary modes of transportation at the gomentum station in concord and at a private business park.
# 0 1 hernandez.
# 0 1 9th, it's <BILL_ID> in the am.
# 0 1 timing does ...time it's ...morning ...more ...
# 0 1 youth give up their rights without understanding those rights, and are more likely than adults to give false confessions.
# 0 1 richard gibson two items.
# 0 1 i'm also proud to add the chair of natural resources as a joined author.
# 0 1 bell.
# 0 1 the motion is due passed as amended and referred to committee on appropriations.
# 0 1 we can appoint to that
# 0 1 thank you very much mr. speaker and members.
# 0 1 i am fully in support of this bill with the amendments.
# 0 1 thank you, those in support, support?
# 0 1 present <BILL_ID> designating this week as california girls and women in sports week.
# 0 1 i know the hour is late.
# 0 1 made myself more valuable so that i didn't have to work a minimum wage job my entire life.
# 0 1 we've added intent language relative to the importance of the three tier system, and
# 0 1 and then military people saw that it had some practical use for them.
# 0 1 as a native of milwaukee, wisconsin, eleanor dichazer,
# 0 1 a broad range of devices already is available.
# 0 1 this item seeing and hearing none senator hernandez she may close
# 0 1 mr bond to.
# 0 1 aye. >> aye, lara?
# 0 1 hi, i'm mary white.
# 0 1 senator hall, welcome to the committee.
# 0 1 that they have relied upon.
# 0 1 substance abuse disorder counselors who meet specific education,
# 0 1 we need to ensure the supports are there to ensure that these providers are paid fairly, especially as the minimum wage goes up.
# 0 1 this was the first in the nation successful school desegregation court case.
# 0 1 ...of served with honor and distinction in la city council many
# 0 1 i think you probably need to keep, you know, to go back and keep working on this some more,
# 0 1 we're also trying to get to the floor.
# 0 1 on some of the other things, to try to increase four-year completion rates.
# 0 1 others that we're going to have an opportunity to address not later in the year, the special session has been called.
# 0 1 i believe secretary ross is here.
# 0 1 item number?
# 0 1 welcome to the senate committee on banking and financial institutions.
# 0 1 i actually think the use of the word require
# 0 1 gaines?
# 0 1 the new language reflects extensive negotiations between all stakeholders.
# 0 1 there's no ceiling.
# 0 1 very frustrating circumstance that really when done responsibility benefits all of us.
# 0 1 any public comment?
# 0 1 there's just not a clear enough path here.
# 0 1 propitious for some national changes.
# 0 1 i'm proud that i stand before you colleagues today and ask for your support of <BILL_ID>
# 0 1 thank you, mr. chair.
# 0 1 all right.
# 0 1 i have a second by mister dodd.
# 0 1 visiting immigrants in confinement, as well as <BILL_ID> other organizations who are supporting this bill,
# 0 1 no, pain.
# 0 1 facilities in california relating to the enforcement of priority seating,
# 0 1 please proceed.
# 0 1 overhhave been victimized.
# 0 1 [foreign] hello and good morning,
# 0 1 keep it short or it's dead on arrival, he said.
# 0 1 education and research is key to timely recognition regarding risks and symptoms.
# 0 1 the problem that this bill has is that the ten year probation is so
# 0 1 after which, please remain standing.
# 0 1 they really are striving for a stronger education.
# 0 1 excuse me, we're going to move to 73.
# 0 1 move to what seems like a productive conversation right now around where this is.
# 0 1 come forward, just say your name, your organization, and your support please.
# 0 1 members, members, we have business before us today,
# 0 1 last remaining steel mill in california.
# 0 1 and please continue.
# 0 1 and let's include our seniors in the silver tsunami.
# 0 1 ious under 100,000 account represent approximately 1% of the iou market.
# 0 1 i'm very much in sympathy with our friends at the newspaper publishers who think the author
# 0 1 seeing no discussion on the item the clerk will open the role.
# 0 1 use the microphone please
# 0 1 aye, morrell.
# 0 1 and so as we take up senator wolk's substitute motion.
# 0 1 senator pavley appreciates that very much.
# 0 1 we support and appreciate the committee amendments
# 0 1 thank you.
# 0 1 the first one was <BILL_ID>
# 0 1 so i appreciate the work today and i look forward to supporting the bill.
# 0 1 so there are two proposals here, the graduation rate improvement plan and the student success network.
# 0 1 our request for that is a budget that allocates $3.2 million in reimbursement authority,
# 0 1 was in a wheelchair and she had cerebral palsy.
# 0 1 but we have, with the collapse of the now infamous ccms,
# 0 1 so we do have 12, it's out, we'll leave the roll open for absent members.
# 0 1 care system of the future, when we get to the item of ccr.
# 0 1 in a safe place and because of our concern for the people we
# 0 1 mr. calderon, you're recognized.
# 0 1 so for what i'm talking about to work,
# 0 1 the clerk will close the role.
# 0 1 take material from a person's heart and built them a new heart that they could use, which before was unheard of.
# 0 1 this is very exciting for them.
# 0 1 the prayer and the pledge will be deemed complete.
# 0 1 private entities as well as local governments as well as, in this case,
# 0 1 we're now allowing, much to my surprise,
# 0 1 he also leaves behind him 18 grandchildren and 8 great grandchildren.
# 0 1 why 10%?
# 0 1 because they're not able to go to all of the meetings around the state.
# 0 1 we have a motion and a second.
# 0 1 thank you, mr. chair and members.
# 0 1 some of those six four by ...member often an
# 0 1 movie business on the daily file.
# 0 1 and we appreciate the senator's leadership to bring it before you today.
# 0 1 first off, with regard to the developmental centers.
# 0 1 seeing and hearing no further debate, the clerk will open the role.
# 0 1 mr. sayed de hini is the founder of the young vision music foundation,
# 0 1 this bill will ensure that counsel representing the child or non-minor dependent will not have a caseload that exceeds 77 clients,
# 0 1 and we will be working with caltrans to respond to the comments that are submitted
# 0 1 ...sand on campus
# 0 1 and there are many people in the latino community that have contributed,
# 0 1 mr. secretary, please read.
# 0 1 senator beall.
# 0 1 thank you madame president.
# 0 1 they will complete this challenge in 42 days.
# 0 1 any other questions?
# 0 1 ...called around campus
# 0 1 constitution, equal population, and compliance with the federal voting rights act.
# 0 1 dababneh aye.
# 0 1 yes, as we've heard testimony.
# 0 1 we want to make sure that they pay as low utility rates as we possibly can.
# 0 1 there's lots of people out there that are in this space and
# 0 1 we.
# 0 1 we think it provides balance and allows for each segment of the industry to thrive.
# 0 1 so, i would ask members to please come down and vote.
# 0 1 as a grandmother, i think of nothing more special than the joy of having a granddaughter
# 0 1 the community comes together, raising money, community partnerships, the boosters,
# 0 1 so members, lastly i wanted to talk about the biden concept because that's false.
# 0 1 no, pan hide heavily.
# 0 1 aye.
# 0 1 reduce unintended pregnancies and also save considerable state dollars as a result.
# 0 1 i have two specific objections to these bills.
# 0 1 aye. >> medina aye.
# 0 1 which signifies everyone that you're applying for licensure, not just to sit for an exam.
# 0 1 <BILL_ID> regarding professions and vocations.
# 0 1 <BILL_ID>
# 0 1 quite an extraordinary sight this measure will ensure that the department
# 0 1 senator wolk?
# 0 1 the clerk will close the roll and tie the votes.
# 0 1 presenting two bills, <BILL_ID> and <BILL_ID>
# 0 1 number real no-win.
# 0 1 ...i am voting no on this bill and i urge you to searcher conferences and vote knows well.
# 0 1 and we're here on this item and
# 0 1 culture-specific celebrations in that particular part of the island.
# 0 1 counseling, parenting classes, supplies for the babies.
# 0 1 asian-american mail to anchor at daily national and cable news show where
# 0 1 move forward to the senate third reading, file item 46.
# 0 1 thank you mr. chair and members.
# 0 1 coupled with lpc, they come up with something, we went through a very thoughtful process
# 0 1 on their own, many cities have proactively adopted ordinances to
# 0 1 it's not per vehicle.
# 0 1 assemblymember waldron, you are recognized.
# 0 1 emotionally i was absent within my body.
# 0 1 ...want to recognize them i also want to recognize our guests in the rear
# 0 1 file items 40 through 48, pass and retain.
# 0 1 file item 70 through 72 pass and retain.
# 0 1 i've practiced immigration law for over 20 years and immigration law is very complex.
# 0 1 ...forty eight is not on my ...
# 0 1 rule some of his many contributions to ensure
# 0 1 in three to five years he will be gone and it's going to be this horrible death.
# 0 1 tally the vote.
# 0 1 restaurants, and neighborhoods that are otherwise struggling and i think it's worth a vote and
# 0 1 the american psychiatric association suicide is an irrational act
# 0 1 glazer? >> aye.
# 0 1 water through recycling or other programs.
# 0 1 there is no opposition.
# 0 1 we need specific laws addressing this, and i would say and consequences that will deter.
# 0 1 and make sure that they put students first and without decreasing the quality of that education.
# 0 1 representing emergency physicians, cardiology which is cardiologists and cardiac surgeons as well as plastic surgeons.
# 0 1 runner?
# 0 1 no, jackson.
# 0 1 and i've toured the facility.
# 0 1 we have our bill, item number 1, <BILL_ID>
# 0 1 pass on file.
# 0 1 file item number 4, mr. secretary please read.
# 0 1 roll.
# 0 1 senator nielson has introduced a motion to move it to the suspense file.
# 0 1 and by passing this bill today, we will get to continue working on it to get it to a place that fully recognizing the strength of that relationship.
# 0 1 it's very ambiguous and which leads to confusion.
# 0 1 [inaudible] about why the liability [inaudible]
# 0 1 members, file item 81, <BILL_ID>
# 0 1 that this population is a significant component of our economy.
# 0 1 aye.
# 0 1 i just know that the best indication of what people will do in the future is what they've done in the past.
# 0 1 gomez? >> aye.
# 0 1 colleagues, we're going to continue on to file item 2, <BILL_ID>
# 0 1 he brings business experience to the board as the founder of several companies.
# 0 1 aye. >> aye. morrell nguyen.
# 0 1 five enjoys near unanimous bipartisan support so it ...to join me in voting
# 0 1 next is 19.
# 0 1 this ensures our customers will be seen seamless.
# 0 1 and so, no one's doing our security because why, if we're given $5,000 and
# 0 1 gomez?
# 0 1 good morning.
# 0 1 homeless coordinating and financing counsel.
# 0 1 named after section 529 of the internal revenue code
# 0 1 then in 2009, the california supreme court said that those of us with commercial coverage,
# 0 1 alan by anderson no base.
# 0 1 hill aye, lara?
# 0 1 lastly, it needs to be recognized that extending copyright over all works protected by public entities is a dramatic departure from the status quo.
# 0 1 <BILL_ID> by assembly member mullin, an act relating to professions and vocations and making appropriation therefor.
# 0 1 beta i bill.
# 0 1 it's item number, what is it, item number 13.
# 0 1 a family members to make that determination for them.
# 0 1 so i believe it's mr. ting that we're waiting on, okay.
# 0 1 okay, at this time, mr bonta, let me just say mr. bonta, thank you for your patience.
# 0 1 as a pt leader in the greater sacramento region for than 16 years, i've seen schools that are doing great things.
# 0 1 we need more of them so let's get to work in getting some funds to
# 0 1 grand juries.
# 0 1 so again, this is a small amount of money to really repair buildings around the state.
# 0 1 bates.
# 0 1 dababneh aye.
# 0 1 and if we're not, then you come with me, everybody that cares about this,
# 0 1 developing, implementing rules and regulations.
# 0 1 all of them in riverside county, aruba valley, east vail metafee and waldemar.
# 0 1 to lift the call.
# 0 1 seeing no discussion on the item, clerk will open the roll.
# 0 1 states without mandatory lost or stolen reporting laws export two and
# 0 1 mr jones sawyer thank you mr speaker ab ten twelve is back
# 0 1 good afternoon.
# 0 1 in the county that represents these projects is supporting this bill,
# 0 1 they said take him home,
# 0 1 thank you, it's a pleasure to be before you this afternoon.
# 0 1 <BILL_ID> by assemblymember gonzalez and others enatualate into evidence.
# 0 1 to not pass this bill would be to strip locals of their ability to manage their case loads and priorities.
# 0 1 a good example of this might be if we chose to regulate beer or energy drinks, or something of that nature.
# 0 1 has an item
# 0 1 file items 18 through 21, pass and retain.
# 0 1 but i went to colarossi down in tulare county, same problem, you had three water districts, very poor water districts,
# 0 1 hold on.
# 0 1 thank you, madame chair.
# 0 1 just a quick question.
# 0 1 i mean, we will when we get our forum, then we'll take our motions.
# 0 1 those fifteen young people by name i want to thank them for their
# 0 1 that's what this bill does.
# 0 1 dispensed with who in the
# 0 1 hard work we're doing locally and they might apply to other jurisdictions as well, but we're here asking as our board is,
# 0 1 it's interesting for your reputation to be sullied in front of your colleagues.
# 0 1 senator huff, i'm reminded that there's currently no opposition.
# 0 1 members voted on.
# 0 1 it would also bring california in alignment with 48 other states that have a coordinating body.
# 0 1 the clerk will read.
# 0 1 members.
# 0 1 it's my pleasure to introduce <BILL_ID>
# 0 1 ...these unprecedented emergency powers again
# 0 1 jean carlos mendez perez, 35 years old.
# 0 1 we're going to go ahead and readjust it.
# 0 1 aye. gaines?
# 0 1 that speaks out against any measure that would propagate hate and violence.
# 0 1 is-
# 0 1 state your name, your organization, your support.
# 0 1 the job skills training program is a concrete step
# 0 1 value when awarding construction contracts assembly amendments narrowed
# 0 1 [inaudible]
# 0 1 rodriguez?
# 0 1 but also around knowing what they want to get out of parent involvement.
# 0 1 as one of the orders, the department issued for the exide facility,
# 0 1 mr. chair, members of the committee.
# 0 1 yes, but if it's polluting a ground water basin, it is a big deal.
# 0 1 and when i saw the proposal i was surprised because it's a one-off proposal.
# 0 1 ...tonight absolutely my thank every single one of you for your hard work
# 0 1 motion in the second?
# 0 1 you know often times we face endeavors that if we just say well we're not going to go there because you don't done it before and then i'll just kind of weather away.
# 0 1 and senator hill, if you'd like to proceed, this is item number 1, members.
# 0 1 thank you. thank you, senator roth.
# 0 1 file item 113, <BILL_ID> weber, the clerk will read.
# 0 1 is there a second?
# 0 1 members if we could have your attention.
# 0 1 thank you, senator pan.
# 0 1 olbernulte's up, let's go.
# 0 1 that artistic director of the actors
# 0 1 thank you very much for the testimony and for that example.
# 0 1 we understand very clearly, the concern is that some local governments are taking advantage of that.
# 0 1 no friends to take them in to help them get back on their feet.
# 0 1 they're very geared towards students academically to enter four year colleges directly from high school.
# 0 1 while fishing is a very relaxing sport, does this include hunting?
# 0 1 i'm jan smutny-jones and i'm very reluctantly in opposition to this, but we continue to oppose this bill.
# 0 1 and particularly with exide, i think lead exposure is dangerous not
# 0 1 moorlach, morell, nguyen, nelson,
# 0 1 mexico's most influential community leaders.
# 0 1 lastly, all sites contemplated for
# 0 1 ...in this process and we may have tightened some of them but
# 0 1 i stand corrected, apparently there is opposition.
# 0 1 yes, senator winn's making my life busy.
# 0 1 or as we want, between charities and political organizations.
# 0 1 aye.
# 0 1 for one, it's being housed with the attorney general to make that determination.
# 0 1 item number three, mr. hill, thank you for waiting patiently.
# 0 1 found that women veterans identifying themselves as homeless more than doubled
# 0 1 chu. >> aye.
# 0 1 thank you.
# 0 1 so now we've identified the hole and
# 0 1 seeing none mrs. secretary, please call the roll.
# 0 1 this is the senate transportation and housing committee.
# 0 1 yes, okay, all right.
# 0 1 ...playwright and poet and novelist cattle rancher.
# 0 1 determine on their own if a candidate has received too much money from a special interest group.
# 0 1 you're good.
# 0 1 per prior agreement, ms. egman, the author of the bill will present and then we will allow ten minutes
# 0 1 an act relating to medi-cal making an appropriation therefore and declaring the urge to take effect immediately.
# 0 1 senator mitchell?
# 0 1 i know it was compelling.
# 0 1 the house today moving to business on the daily file.
# 0 1 why would a us president remain silent
# 0 1 the community association institute remove their opposition with the recent amendments, and i urge an aye vote.
# 0 1 ...rate ...formula fourteen ninety two by some number ...and others and actually the
# 0 1 i'd first like to thank the author and sponsor.
# 0 1 there are others that fall short and systematically deny certifications on the basis of political views or immigration matters.
# 0 1 business professions in economic development for our hearing on monday, june 6th.
# 0 1 okay, members, returning to announcements and then adjournments in memory.
# 0 1 what you want to do is, you want to try to match your cash flow to a project that
# 0 1 etc who have been working with mr. weinberg and myself, to harmonize
# 0 1 ...without reference to file a ...six four senator bill?
# 0 1 i'm going to begin with <BILL_ID>
# 0 1 members in file order.
# 0 1 clerk will close the roll, there <BILL_ID> co-authors added.
# 0 1 can pay uc and so we can get you better data on
# 0 1 file item, we're going to go back to file item 169.
# 0 1 but since <BILL_ID> specifically required the measure to go on the november 14 ballot,
# 0 1 members, we are going to take up file item number 90, <BILL_ID> by mr. cooper.
# 0 1 a lot of these financing structures that solar companies are using in
# 0 1 my name is lisa lopez.
# 0 1 aye, pan?
# 0 1 protect consumers against sub standard new fuels and products which could negatively
# 0 1 firefighters, emts, all train now on del campo's field
# 0 1 we are regrettably in opposition to the bill.
# 0 1 ...nielsen ...
# 0 1 sometimes because we have been slow to act on the issues they want.
# 0 1 pass on file.
# 0 1 a file item forty five-cent bill six twelve.
# 0 1 about where you are when you're voting we went back to the rules
# 0 1 under assembly third reading item twelve item twelve.
# 0 1 an unequal access to government, in my view, is a problem.
# 0 1 it prevents the ctc from using california taxpayer monies to support coal export projects,
# 0 1 mr. salas, you too are recognized.
# 0 1 good afternoon mr. chair and members.
# 0 1 a couple of announcements first of all.
# 0 1 jewish american heritage month and this individual,
# 0 1 that's why my back is all cramped up, because.
# 0 1 we have a special order upon the adjournment of our session,
# 0 1 [inaudible] and reviewing.
# 0 1 i appreciate the goals of this as well as ms. olsen's comments there.
# 0 1 i'm sad to say, i'm disappointed to say, that the board of state and community corrections,
# 0 1 a lot of us to eat the food that we eat and to go into buildings that are clean.
# 0 1 the legislature would have to pass another bill to pitch it on a future ballot.
# 0 1 order of center gala gianni excuse me.
# 0 1 but we're trying to make sure that we're setting a standard here and saying that
# 0 1 that's <BILL_ID>
# 0 1 14 to 0, the measure passes.
# 0 1 and i think with that, we can answer any questions that you may have, thank you.
# 0 1 my understanding is that assembly member gallagher did make
# 0 1 so strongly oppose this bill because essentially they've, they've been stranded.
# 0 1 ...none is there any objection to the use of a previous roll call.
# 0 1 and [unknown] firearms.
# 0 1 fentanyl is up to 50 times more potent than 100% pure heroin.
# 0 1 but what this would do is as individuals transfer out and into the community setting,
# 0 1 thank you, senator gaines.
# 0 1 i would.
# 0 1 in mccutcheon, the court has also identified the one legitimate government interest for
# 0 1 to address i think we call it the problem with litigious.
# 0 1 which is a very large amount of the population and
# 0 1 aye.
# 0 1 and then a $20 million settlement with sutter which is being paid off at $2 million a year for the next ten years.
# 0 1 incredible points and i think he's laid the frat the groundwork for some serious work next
# 0 1 file ...sixty through sixty three.
# 0 1 i ask for your aye vote, thank you very much madam chair.
# 0 1 procedure because quite frankly no one really knows what's happening in those
# 0 1 but i do advocate, if we're going to give benefit to such things as this, that we do pay heed to our highest priorities.
# 0 1 we voted some clarifying conditions in the state of california ensure to reduce frivolous lawsuits.
# 0 1 when doing many acts of official business like registering to vote, enrolling your children in school, and other things.
# 0 1 i want to tell you the story about a case we just had a couple of years ago.
# 0 1 everyday californians to understand these problems and help create the solutions to a tragic epidemic.
# 0 1 thank you mr. gonno.
# 0 1 aloha [unknown] is an education committee.
# 0 1 possessing approximately a third of a gram of heroin for sale.
# 0 1 so again, it's not asking those buses that are expected to get additional inspections.
# 0 1 house resolution 53 by senator gonzalez and others relative to immigrant heritage month.
# 0 1 refineries, our southern california refineries are growing increasingly concerned about this summer and
# 0 1 resolution of bringing back the historic names of locals in yosemite.
# 0 1 eight zero your bill is out.
# 0 1 concerns raised by the administration i would ask fear i votes and concurrent
# 0 1 hope we have the votes.
# 0 1 thank you. sees assemblyman hernandez.
# 0 1 ...not really about electric skateboards but about the possibility of
# 0 1 ...this become quite ...deal over the last few years.
# 0 1 be prosecuting these kids against their will that are in this business.
# 0 1 i'm presenting additional motions, resolutions and notices.
# 0 1 that bill is out.
# 0 1 lastly i'll just say that, and it's been brought up a couple of times today, california's international role and
# 0 1 population of turkeys, broilers, and laying hens.
# 0 1 i'm happy to introduce to you my first young senators class that graduates this friday from 2016.
# 0 1 aye.
# 0 1 my understanding there is support of both sides.
# 0 1 we are in a tweener position, we are trying to find clarity on this bill for
# 0 1 under unfinished business file
# 0 1 seeing none, aye's 36, no's 0.
# 0 1 okay.
# 0 1 file item seven is <BILL_ID> clerk will read.
# 0 1 aye.
# 0 1 seeing and hearing none, ayes 39, nos zero, the measure passes.
# 0 1 aye.
# 0 1 <BILL_ID> will phase out the use of the derogatory racial slur, the r word, as a school name, mascot, or nickname.
# 0 1 <BILL_ID>
# 0 1 so, let alone what it's doing to all the working class students out there
# 0 1 [inaudible]
# 0 1 aye.
# 0 1 operations grants, it takes a significant investment to get a teaching health center program launched.
# 0 1 thank you for asking the members.
# 0 1 the need to have quality, affordable and accessible child care for their children.
# 0 1 right. so that's where we'll be working with the csac, and hcd will be working with those individual counties
# 0 1 i do think that this notion, especially with the driver's license thing you're doing, electronic stuff is part of this.
# 0 1 from within our great nation, is a venom that we collectively as
# 0 1 and mr. chairman, may i have permission to read?
# 0 1 it this is been a source of great personal labor.
# 0 1 in places like watsonville and salinas and were sent to rodeo grounds, and
# 0 1 good afternoon.
# 0 1 since joining the cal poly faculty in nineteen sixty nine doctor bailey has a
# 0 1 needs to continue to work and we need to prioritize this in january and get a
# 0 1 final item 35, <BILL_ID>
# 0 1 thank you one.
# 0 1 i'm trying to understand the rationale here, we're dealing with
# 0 1 our customers are not necessarily paying for leaks that are completely outside the utilities control.
# 0 1 to identify a dedicated revenue source to pay for those reimbursements.
# 0 1 they're simply one of many ways in which the healthcare system is trying to develop more evidence-based treatment programs and options.
# 0 1 okay.
# 0 1 mr. holden, you're here before us with a do pass [unknown].
# 0 1 we also have [unknown] of the city of artesia.
# 0 1 me, and we have yet to have a quorum, so we need to establish quorum before we can take a vote on that.
# 0 1 and we need to start thinking about why that is necessary
# 0 1 members we are back in session.
# 0 1 mr. chairman and members of the committee.
# 0 1 same thing, don't take the money out of our pocket.
# 0 1 no. gaines no.
# 0 1 in fact, our forests are choked and overcrowded with this species, because of a lack of markets.
# 0 1 ...i want to thank the chair the health committee for spending
# 0 1 leader who only spoke.
# 0 1 that this provides them the ability to take the money with them at
# 0 1 in the last couple of years, mr. president,
# 0 1 leno?
# 0 1 <BILL_ID> is a public safety measure which seeks to ensure the safety of passengers utilizing tnc services.
# 0 1 thank you mr. chair and members.
# 0 1 we don't have mr. hernandez here.
# 0 1 by what.
# 0 1 the working drawings to be completed in the 2016 17 fiscal year as rather than the 2015 16 fiscal year as originally planned and
# 0 1 i think we've got 10 5.
# 0 1 other activities throughout the day, and night on the daily basis.
# 0 1 yes i am, thank you.
# 0 1 first of all, madam chair, under motions and resolutions.
# 0 1 ...going to go back in the file to mr moans item
# 0 1 makes a good case, but again, i think there's probably a spectrum of the level of,
# 0 1 this is based on workload created by the people that
# 0 1 some spoke about already and others to insure that we are having
# 0 1 we're just doing motions and seconds, so you can-
# 0 1 this is simply, what i'm trying to understand is why.
# 0 1 again, one other thing on the notice.
# 0 1 really appreciate the senator's approach, really appreicate the staff's approach to reaching out early,
# 0 1 thank you and thanks for working so closely with out committee on this and
# 0 1 file item 35 senator mitchel.
# 0 1 good morning, chair and members.
# 0 1 line seven when you're defining cigars,
# 0 1 hancock, aye.
# 0 1 ...one for concurrence which will help local governments ...green ways
# 0 1 it's a full-house.
# 0 1 we've seen this with other dangerous substances before that fda did not want to regulate it.
# 0 1 all members vote who desire to
# 0 1 any additional witnesses in support?
# 0 1 senator roth, you have <BILL_ID> sir.
# 0 1 i gains by gaussian only i ...
# 0 1 mr. gallagher you have two minutes to
# 0 1 and then lastly, the bill provides a sense of urgency around
# 0 1 the assembly is back in session.
# 0 1 why this amount is needed and why a lesser amount would be insufficient.
# 0 1 i hope you had a very productive week with family, with loved ones, with constituents.
# 0 1 this is about some goofball who found a platform for
# 0 1 item number 10, <BILL_ID> due pass to judiciary.
# 0 1 good morning.
# 0 1 and more so since 2003, when our last framework was adopted.
# 0 1 recommends programs such as the one we're proposing.
# 0 1 we've been working on this matter now for a year with assemblymember daly, trying to work this thing out.
# 0 1 ...this row whose article on members vote who deserve a vote all members vote who
# 0 1 they had a long tie over the decades with king and his family.
# 0 1 644 thousand dollars in this years budget.
# 0 1 accredited by the aza use a bullhook either, and haven't for more than a dozen years.
# 0 1 there's people believe that this can help the mental health.
# 0 1 thank you, madam president, colleagues, i ask for your aye vote.
# 0 1 thank you.
# 0 1 ladies and gentlemen of the senate, i have to vote no as well.
# 0 1 file item 139, 1654, clerk will read.
# 0 1 he is a member of the arizona governor's council on spinal and head injury, the special committee of the us brain injury association,
# 0 1 thank you ...remembers members this is the month that we honor social
# 0 1 i want to make that clear, file item 12, <BILL_ID> by assemblymember wagner
# 0 1 for example, a utility district provided me with some analytics from their web page.
# 0 1 i'll lay off of this this time, but i really believe that we need
# 0 1 choosing instead to remain incarcerated to allow her case to continue through the system.
# 0 1 this is simply a clean up of a budget problem,
# 0 1 you.
# 0 1 pro replication hearings to the criminal trial courts the statutory
# 0 1 thank you mr. chairman.
# 0 1 but we give these people raises so these are people who have
# 0 1 as we fight the ongoing conflicts in the middle east.
# 0 1 good afternoon, mr. vice chair and members,
# 0 1 care for and all of the fun and excitement of the county fairs.
# 0 1 and it's mostly focused on smaller businesses and
# 0 1 so i think as long as you keep seeing new issues and
# 0 1 i try hard, mr. chair, i try hard.
# 0 1 mr. mathis is 1-3, we will hold it open,
# 0 1 i would like to respectfully request to remove <BILL_ID> and 127 from the inactive file.
# 0 1 so i'll make that motion.
# 0 1 we will stand in recess.
# 0 1 what we need is life and we need love.
# 0 1 something the current board member can do with one majority vote and ratification if 16 member city councils.
# 0 1 mr. dodd, your bill, <BILL_ID>
# 0 1 aye.
# 0 1 because they just figure well, if we can just continue to put pressure on you, eventually you'll just agree to settle.
# 0 1 thank you, ms. gonzalez.
# 0 1 channel the theory chapel is one of california's oldest historical buildings
# 0 1 has an attendance policy that prohibits the child from attending or
# 0 1 i do however have a concern as i know a lot of people do that this action would negatively affect the energy stability of southern california.
# 0 1 file items 12 and 13 pass and retain.
# 0 1 again item 5180, department of social services,
# 0 1 jewish culture has been attempted to be suppressed from the bar kokhba revolt 2000 years ago to today.
# 0 1 i'm a real.
# 0 1 senator, i-
# 0 1 we do not need your officials to do so.
# 0 1 aye 67, noes 0, measure passes.
# 0 1 and with smoke coming out of the tailpipe, it would create black cloud.
# 0 1 ...yes all right senator wind please thank you thank you senator?
# 0 1 it does seem everybody is now accepting ebt.
# 0 1 medina.
# 0 1 only about a quarter of them have adequate latino representation in those.
# 0 1 by promoting comprehensive solutions to increase and improve the urban environment,
# 0 1 the testing is conducted, and results are submitted.
# 0 1 which highlights why it is so important that smokers have the help that they need to end their nicotine addiction.
# 0 1 just so you know that agriculture does
# 0 1 going to
# 0 1 jim venible leaves behind a significant legacy in riverside county.
# 0 1 daughters our grandchildren women hold up half the sky and unless and
# 0 1 all right, thank you mr. harris.
# 0 1 aye runner.
# 0 1 ...rail followed by senator runner.
# 0 1 is all senate members to the senate floor to continue and
# 0 1 let me just say first off, that the vast majority of public water systems
# 0 1 which spreads huanglongbing which kills citrus trees.
# 0 1 yes, mr. antuit, would you like to say a few words, please?
# 0 1 yes, thank you very much.
# 0 1 thank you members.
# 0 1 encourages california to celebrate accomplishments and traditions of this important group.
# 0 1 good morning.
# 0 1 rather california allows those who are working hard to become licensed engineers and
# 0 1 i'm curious, was this technology available before the leak?
# 0 1 [inaudible].
# 0 1 ...a concurrent resolution ...senator gains relative to mentoring month.
# 0 1 continue to pass on items there's no guarantee that we will return to them so,
# 0 1 i also serve on the california state council on developmental disabilities, where i chair the legislative and public policy committee.
# 0 1 it's a tough vote, tough cases, but vote no.
# 0 1 today's prayer will be offered by father pappademas.
# 0 1 witnesses in opposition?
# 0 1 is a fundamental human right at the end of life people
# 0 1 and today, we would like to work with you on that.
# 0 1 now we'll call file item number 9, <BILL_ID>
# 0 1 and hd young who was the co-founder of the san francisco chronicle and she was a long-time board
# 0 1 i have had numerous constituents contact my office who have received these tickets, and have been devastated.
# 0 1 thank you mr. president and members.
# 0 1 we will now move to the presentation.
# 0 1 all right, now chair, there you go.
# 0 1 gaines.
# 0 1 sit down.
# 0 1 any debate or discussion?
# 0 1 blocked by ...daily on fuller.
# 0 1 i think it makes great sense.
# 0 1 hueso.
# 0 1 if there are health committee members out there, please come.
# 0 1 today we conclude our session on the eve, pretty much on the 4th of july.
# 0 1 here we go, so back in some of the budget reductions in
# 0 1 fully recognize and do their part to make sure that we
# 0 1 i rise in support as a co-chair of our bipartisan legislative technology and innovation caucus.
# 0 1 but within the context of the state of california, the unreal act, and what california stands for,
# 0 1 aye. >> aye, fuller, gaines, galgiani,
# 0 1 as it turns out, that day was just the beginning of our family's nightmare.
# 0 1 so even if he came back into care at 19 years old, as a transitional age foster youth,
# 0 1 file item 66, assembled 1163, rodriguez.
# 0 1 and i've talked to a number of members in this committee about that, and
# 0 1 to reinforce california's water infrastructure the action we
# 0 1 we'd like to ask people to turn their cell phones off so that we can hear testimony.
# 0 1 vice chair mr. jones, as mr. thurman and i prepare our presentations,
# 0 1 the number of staff we currently devote to this work, and
# 0 1 the human spirit as well i ask for your ivo.
# 0 1 thank you, sir.
# 0 1 we can't really stop the demand,
# 0 1 hancock.
# 0 1 sergeants are handing out stockmen.
# 0 1 originally from detroit, he moved like so many young musicians did to la.
# 0 1 which i believe some of those are actually recorded here in the building.
# 0 1 this bill spa 15 would implement the hospital related provisions of
# 0 1 thank you.
# 0 1 specifically this bill was informed by the state controller's audit in west covina within my district.
# 0 1 yes, okay.
# 0 1 especially in the area of solid waste these drivers, they know the neighborhoods, they know the routes, they know the equipment.
# 0 1 respect their question i vote thank you senator morning debater discussion
# 0 1 file item 295 members?
# 0 1 consistence with graduation default
# 0 1 who desire to vote clerk will close role
# 0 1 which is a complete betrayal of what we, as a government ought to be doing.
# 0 1 thank you.
# 0 1 thank you, mr. chairman, ron kingston representing some regional apartment associations,
# 0 1 likewise what we saw today, will be reaped by others again.
# 0 1 runner?
# 0 1 members we're going to pass temporarily on item 105 and take a one hour recess.
# 0 1 encourages all our citizens to show support for those with autism during the month of april.
# 0 1 cyber bullying is not defined in this piece of legislation.
# 0 1 seeing and hearing nine the clerk will read the second day consent calendar and some level one sixty
# 0 1 wait, you're skipping, you're skipping.
# 0 1 ...members wrote who deserve a vote ...members ...who ...vote.
# 0 1 file item 112, <BILL_ID> stone, the clerk will read.
# 0 1 cannella? >> aye.
# 0 1 thank.
# 0 1 and, my
# 0 1 item number 24, <BILL_ID>
# 0 1 file item fifty six.
# 0 1 but it has a chance.
# 0 1 all members ...desire to vote.
# 0 1 we expect miss rogers to hang around the rest of the time so it's good stuff.
# 0 1 and so what this bill does is this asks the public utilities commission to start looking at tariffs to align both.
# 0 1 yes. >> murrell, aye.
# 0 1 we will amend it before regardless of the self execute if that's consistent with your bill and the-
# 0 1 nielsen, aye.
# 0 1 members, back on the file.
# 0 1 thank you very much, members and mr chair.
# 0 1 our recording system, it is designed to give people notice of official documents.
# 0 1 okay, let's get back.
# 0 1 senator anderson.
# 0 1 fuller.
# 0 1 and he was a patriarch, always able to share family history, community history for being so involved in the family.
# 0 1 we are going to take up <BILL_ID> by mr.
# 0 1 to the point, today, la metro is managing the 710 north project.
# 0 1 good morning.
# 0 1 thank you.
# 0 1 thank you. any discussion or debate?
# 0 1 we think there is a way to integrate iid into remedies we believe at case by case basis the best way to go.
# 0 1 that is linda cook as well as his mother, patricia.
# 0 1 it's citations.
# 0 1 ...paul hancock and it is
# 0 1 this legislation caps it at 10%.
# 0 1 item number ten, <BILL_ID> motions do pass as amended to appropriations.
# 0 1 file item 34.
# 0 1 questions or comments from the committee?
# 0 1 so regretfully, what's going on is not alone in the cities that have violated the public's trust.
# 0 1 many times it comes from the public sector, which means that tax payers are footing
# 0 1 yes, thank you, madame president.
# 0 1 colleagues,
# 0 1 the clerk will close the roll, tally the vote.
# 0 1 the resolution is adopted.
# 0 1 and supported it becoming mandatory.
# 0 1 in the next two years, providers were reduced by another 4.25%.
# 0 1 but most important, most important anyone
# 0 1 veiled and alfred song memorial monument outside the metropolitan
# 0 1 file item 211, senator mendoza, mr. secretary please read.
# 0 1 all members ...
# 0 1 thank you again mr speaker i'm joined here by many individuals from all over this
# 0 1 <BILL_ID> will also authorize csat to acquire electronic submission
# 0 1 by the way, so you're asking them to use their private money to support your speech,
# 0 1 i'll take my lower assessment but into a cheaper house so
# 0 1 i respectfully ask for your aye vote, and here to testify for support of this bill.
# 0 1 while emphasizing the critical need for ongoing.
# 0 1 and which component to amendment four is it?
# 0 1 of chief warrant officer before he retired from the reserves in 2011.
# 0 1 seeing no discussion or debate on the item, clerk will open the role.
# 0 1 members.
# 0 1 the prescribed data to the secretary of state is likely to be significant.
# 0 1 this bill deals both with our developmental centers and our regional centers.
# 0 1 and it's not just the medi-cal students and it's not just the ones that ip is written on, it's all students.
# 0 1 have problems looking for housing thereafter, so thank you.
# 0 1 for our community colleges we're able to fund enrollment growth of 3% making sure we address workforce needs.
# 0 1 it's a registry program.
# 0 1 i don't think a state law change can undo a signed binding agreement.
# 0 1 hearing and we're going to take assembly when melissa melinda is out of order
# 0 1 clarifies that bona fide private mail delivery company is a for-profit
# 0 1 good morning, senator.
# 0 1 journals for march ninth through
# 0 1 thank you mr speaker ...questionnaires consent to suspend ...sixty
# 0 1 we've been able to work things out between ourselves, without having to resort to the court system.
# 0 1 and in the 30+ years that i have lived there, i have never remembered the water so warm.
# 0 1 this is probably not an appropriate, if you're giving testimony that's great, questions, you can do that offline.
# 0 1 when i answer those questions.
# 0 1 first, jen masooca, who's president and ceo of cal non-profits.
# 0 1 so it is with great honor members that i present this resolution to ms.
# 0 1 okay.
# 0 1 <BILL_ID> by senator hancock.
# 0 1 ...request your ivo thank you.
# 0 1 [inaudible]
# 0 1 a proper balance must be made to give due considerations to the impact on school districts,
# 0 1 she was born in 1936 as a fourth generation californian, and
# 0 1 seen in hearing no further debate on this magnificent bill the click ...
# 0 1 file items seventy eight.
# 0 1 they are victims.
# 0 1 what we call 2567s in april 22nd of just last month.
# 0 1 trisha garringer, agricultural council of california, in opposition.
# 0 1 we do have some continuing concerns, but we do have to acknowledge the author's efforts to talk to us,
# 0 1 our yorth are saying, this is what i want to be.
# 0 1 we must respectfully remain in opposition to <BILL_ID>
# 0 1 bell.
# 0 1 serial drug dealers with enhanced penalties may well have the opposite effect,
# 0 1 you intend to be, now's the time to get off the bus.
# 0 1 i mean we want people to be able to understand what's going on particularly when you have something socially,
# 0 1 we want it available to anyone who comes here and be able to get the benefit from it.
# 0 1 good afternoon.
# 0 1 the department of healthcare services will have a community mental health services overview.
# 0 1 a simple cold instead of having them be able to see a doctor.
# 0 1 to find this a pretty disingenuous way to blame the uc for
# 0 1 he went on to get a degree from stanford university and
# 0 1 to mandatory 45 days 90 days for second, third offense.
# 0 1 she was active in her community volunteering with st. patrick's catholic church in kerman.
# 0 1 those in support.
# 0 1 leyva, aye.
# 0 1 just setting for the powers that are available to localities on this issue and
# 0 1 sometime <BILL_ID> there was a, i think it was <BILL_ID>
# 0 1 and that's the problem with trying to use nuisance.
# 0 1 so, item number four <BILL_ID> miss waldron.
# 0 1 i believe it is, mr. chiu next, <BILL_ID>
# 0 1 ...hearing the comment that was made
# 0 1 so, again, we're in ...unfinished business of the regular file.
# 0 1 aye, hernandez.
# 0 1 one of the most important things to have when you have such a high mortality is
# 0 1 there are laws on the books to prevent the illegal loaning of firearms.
# 0 1 any public comment on the overview?
# 0 1 let's continue that mission and
# 0 1 thank you.
# 0 1 this allows students who might require a course online to cross-enroll
# 0 1 adrenal fatigue, cancer, fibromyalgia, chronic fatigue syndrome, and many, many more.
# 0 1 senator roth.
# 0 1 for <BILL_ID> is that correct?
# 0 1 cherished member of this senate family because it is his
# 0 1 those rates are set forth through a process.
# 0 1 gomez?
# 0 1 ayes 69, noes 0.
# 0 1 because to me it's a more perfect statement for
# 0 1 rejuvenation and to look deeply into the human condition, in addition to the green world in which we live.
# 0 1 okay.
# 0 1 the bill has received broad bipartisan support and i respectfully ask for your aye vote.
# 0 1 just quick comment, mr. chair, thank you.
# 0 1 if a ballot measure passes, we won't be able to change it, if we need to change one word of that language.
# 0 1 mister dahle we share the same goal in reducing gun violence.
# 0 1 this amount is consistent with the administration's multi-year funding proposal for all of the r public higher education segments,
# 0 1 and that's why i'm recommending a support, and the recommended motion is due pass.
# 0 1 appliance standards to deliver the efficiency savings that we're expecting.
# 0 1 afford to reduce their reliance on carbon intensive energy sources.
# 0 1 i talked earlier this year on the minimum wage and i talked about the extent to which
# 0 1 the preschool foundations were developed, the curriculum standards that we use.
# 0 1 file item 9 <BILL_ID> chavez.
# 0 1 we're on <BILL_ID> block.
# 0 1 berryhill, cannella
# 0 1 aye, hernandez?
# 0 1 mr. chairman and members.
# 0 1 it's nine seven senators please come to the senate floor so we can begin.
# 0 1 i just want to say i resent,
# 0 1 bloom, aye.
# 0 1 colleagues a quorum is present.
# 0 1 standard screening colorectal cancer includes stool blood tests and a colonoscopy.
# 0 1 yes, i'd be happy to address some of the comments that were made.
# 0 1 mfds are recognized by the state as medical providers but recognized as such in clinic settings for purposes of billing.
# 0 1 i have seen the downstream effects of not having a policy where we treat people with respect.
# 0 1 all right, we have a motion by
# 0 1 i'm here to represent the student who just like me, don't know where to go to seek information about health insurance.
# 0 1 senator leyva, you have item 2, <BILL_ID>
# 0 1 business on a daily file, second reading, clerk will read.
# 0 1 measure passes.
# 0 1 welcome to our april 20th budget sub committee number three hearing.
# 0 1 however confir and coahcmen is currently threatening the existence of oakwood woodlands that are so beneficial for people, wildlife, and the ecosystem.
# 0 1 move the bill.
# 0 1 199, 202 and 203.
# 0 1 two days preceding the interim recess on bills that pass.
# 0 1 we do.
# 0 1 aye, anderson?
# 0 1 sailor.
# ...
# 1 0 these monitors have been extremely effective in ensuring that the legislature
# 1 0 in terms of the metrics, the report, i think the survey study done by the water replenishment district in southern california.
# 1 0 and jeff tong, he's president of the california council of the blind and legal counsel, he's here to answer any questions you may have.
# 1 0 because again it does play off calepca but that's the definition we use.
# 1 0 the dire need that this teacher shortage has presented us with is why i'm here to support this bill.
# 1 0 ...also which everyone a healthy and prosperous ...new ...well as of course and celebration
# 1 0 placer county health county officer, dr. robert olden on behalf of the health officers association of california,
# 1 0 california now has the distinction of having the two most recent excavation related death,
# 1 0 posting the notice in a place where employees gather, and it wasn't clear from my reading of the bill whether or
# 1 0 meeting on behalf of surrounding fisher thank you.
# 1 0 oftentimes, when you go down to the va, it's not a i'm going down for a one hour appointment.
# 1 0 by hole.
# 1 0 we're working with oes and i'm open to that suggestion as well, even just one.
# 1 0 so let's properly calibrate these high dollar civil penalties according to facility size so
# 1 0 this request is for $1.15 million over
# 1 0 moving on to senator leno's items, <BILL_ID>
# 1 0 previously, ross served as deputy secretary of the california business consumer services and housing agency and we have her back and we're better off for it.
# 1 0 it was very thorough engagement with behind the scenes,
# 1 0 it's a big issue in orange county.
# 1 0 we think this is important just so staff are kept aware of the kind of decision that are going to be made about the project.
# 1 0 i'll move approval, mr. chair.
# 1 0 and i'm proud to have with me the mayor of the city of oakland, the biggest city of my district, mayor libby schaaf.
# 1 0 i think that this bill would directly harm our individual home owners.
# 1 0 ...served in many critical leadership positions including as the
# 1 0 an emphasis on the rehabilitation piece of this.
# 1 0 i respectfully ask for your aye vote.
# 1 0 <BILL_ID> an important bill for the county of san diego because it will ensure
# 1 0 because right now i have denials that say we will not cover any treatment between the hours of 9:00 and 3:00.
# 1 0 i mean, in some districts the involvement is, i don't know who developed the plan, but there's a meeting.
# 1 0 and understand, historically, ground water has always been viewed with one case law exception as a private property right.
# 1 0 that's luis valdez who wrote the zoot suit and other plays.
# 1 0 all members vote who desire to vote.
# 1 0 i'll be voting no on your bill today.
# 1 0 i respectfully ask for your aye vote.
# 1 0 the state provides resources in form of grants to non profit agencies to provide housing, mental health,
# 1 0 i'd like to introduce david de meers from the california association
# 1 0 and their punishment when violating the protective order would not include the appropriate domestic violence terms such as the batterers treatment program,
# 1 0 the california district attorney's association, and the california state sheriff's association and numerous other law enforcement groups.
# 1 0 there was prop one money allocated earlier this year through department of water resources to create groundwater plans.
# 1 0 aye. >> lopez, aye.
# 1 0 aye. >> aye, liu?
# 1 0 i ask for your aye vote.
# 1 0 we're going to have lobbyists and witnesses, come to your house and rearrange your furniture.
# 1 0 so we have considered the possibility of litigation savings, but believe that there will be net costs.
# 1 0 let's move onto 5180, department of social services child welfare services.
# 1 0 2375, purge committee.
# 1 0 and evan, her 11 year old son, who has autism but is not defined that way.
# 1 0 i respectfully ask for you aye vote.
# 1 0 ...two five one is back on concurrence various clarifying
# 1 0 mr. o'donnell, you may open.
# 1 0 i've been inspired by everything that's been said on this floor.
# 1 0 seeing none, any members of the public that would like to testify in opposition to the author's bill?
# 1 0 thank you. >> thank you, mr. chairman and members, really appreciate your vote.
# 1 0 the problem you've seen recently with the potential strike action of our brothers and
# 1 0 he goes on to say that there should not be any equivocation on the subject.
# 1 0 that are reasonable should and can continue, and that's the essence of the bill.
# 1 0 aye moorlach, no morrel, no nguyen, no nielson,
# 1 0 yes, yes, mr. mcguire.
# 1 0 we're moving to file item 270.
# 1 0 moving on to file item 130, members, senator leyva.
# 1 0 pursuant to senate rule 2910.
# 1 0 we'll be led in the pledge of allegiance to the flag by senator hueso.
# 1 0 this rifle was invented by some folks in southern california primarily as a civilian use rifle,
# 1 0 we would review that with the secretary of state's office as part of our normal fall budget process.
# 1 0 moore's law says that we are in, from a technology standpoint, every 18 months, when you look at the studies, we're doing it even faster.
# 1 0 additionally, we believe it can result in general fund costs that are not included in the administration's current fiscal plan.
# 1 0 familiar with the fishing practices along their coasts that may be of
# 1 0 proven way to bring physicians to the area than through these types of residency programs.
# 1 0 saving money for our state poor families with children.
# 1 0 lackey not voting.
# 1 0 which the legislature has reauthorized on three different occasions.
# 1 0 these projects will create a real impact on californians and
# 1 0 of course, on an annual budget allocation.
# 1 0 i respectfully ask for your aye vote members.
# 1 0 thank you, mr president, i'm honored to present this resolution with my joint author, senator galgiani.
# 1 0 the two million undocumented immigrants living in california.
# 1 0 this bill is important to me for both personal, and professional reasons.
# 1 0 we have voted on sebas, or mister ridley thomas' bill.
# 1 0 has no elected members, and so where's the oversight in terms of implementation of regulation?
# 1 0 there are no absences today.
# 1 0 but by 1945, 12 years later, most european jews, two out of every three, had been killed.
# 1 0 while still maintaining continued oversight of bus operators with a satisfactory track record.
# 1 0 so that there is not a de facto control of that nonprofit charter school by the for profit entity.
# 1 0 cost-cutting measures i ask you for no vote.
# 1 0 these changes will protect rate payers by ensuring that the transactions recorded in balancing
# 1 0 and this bill actually goes even further and requires dna collection in every misdemeanor
# 1 0 any discussion and debate any objection to use of unanimous roll call.
# 1 0 i rise today to present <BILL_ID>
# 1 0 returning to file item 87 <BILL_ID> irwin, the clerk will read.
# 1 0 number fifteen ...thank humor present average me
# 1 0 all right, so senator jackson's fill in.
# 1 0 and we are set, we are at a rate, excuse me, at a place where the economy of scale for
# 1 0 one, our concerns have been noted in the staff comments.
# 1 0 do it right now if you don't mind.
# 1 0 activity carried out with public resources on public time.
# 1 0 and that reaches the range of damages in the tens of thousands.
# 1 0 members, just as an reminder we have already invested in these students and
# 1 0 and, then establish the trinity players up on that small county.
# 1 0 we're sort of heading towards the tail end of this day session, we'd like all members on the floor.
# 1 0 mcguire.
# 1 0 for 15 years, we have denied basic needs assistance to our most vulnerable citizens, extremely poor infants.
# 1 0 aye, leno?
# 1 0 and that's the responsibility of the various corporations and
# 1 0 thank you, senator wieckowski.
# 1 0 it's a difference in opinion.
# 1 0 we certainly thank the author for bringing it forward.
# 1 0 and so by doing this bill, we hope that not only on the employee end, but also the employers could also
# 1 0 the march toward lbgt equality is a long arduous and bitter sweet one.
# 1 0 just have the court set on their calendar, 59 day if this thing has been resolved then dismiss it i bet.
# 1 0 and how do you recommend that the department of fish and
# 1 0 motion is do pass to the senate rules.
# 1 0 is it for purposes of, who will use it i should ask?
# 1 0 stone?
# 1 0 so we all agree upon that and what this bill actually captures is the balance that we actually do consider prior compensation.
# 1 0 i'm presenting <BILL_ID> to provide clear standardized set of regulations for
# 1 0 joe michael for equality california.
# 1 0 to this bill would be similar in creating a body of criteria that would determine rehabilitation and
# 1 0 unless doubted the received a surprise bill i know i have thank you this
# 1 0 good afternoon, andrew martinez, california state university system.
# 1 0 pursuant to a...ninety six...question
# 1 0 of external affairs i did share with him this would be his best post just so,
# 1 0 because an officer can be spending an abundant amount of his time doing paperwork rather than being on the streets and doing community-oriented policing.
# 1 0 our friends, neighbors, and loved ones.
# 1 0 members, to bear discussion on this item?
# 1 0 members, i respectfully urge your aye vote on this measure.
# 1 0 if you could please come forward, state your first and last and your organization.
# 1 0 arts access at our local regional center through free tickets but also
# 1 0 advantage of cost effective energy efficiency and water conservation measures in state facilities.
# 1 0 not only do we have the base funding that has been in the prior years, for statewide of about $68 million.
# 1 0 secretary, please call the absent members.
# 1 0 will provide more bang for the buck, because the home buyer programs is really a lottery.
# 1 0 he can come to us.
# 1 0 you wouldn't know that it was a transit bus.
# 1 0 this amount could've been used instead to purchase for students 1,570 textbooks, 625 chrome books,
# 1 0 mr. stone, you're recognized.
# 1 0 extending basic constitutional protections to our digital information.
# 1 0 and then now my dentist, they're not even open on friday
# 1 0 and save state dollars along the way.
# 1 0 the second issue is the lead exposure proposals.
# 1 0 aye. >> aye, nielsen?
# 1 0 stone?
# 1 0 hurt litigation and lastly number six gives the state department of public health
# 1 0 harper? >> not voting.
# 1 0 and so that's the thing that i celebrate these young men mostly about is their character, and determination.
# 1 0 i'll be more than willing to hold off on a vote today to give us more time
# 1 0 i respectfully ask for an aye vote, thank you mr. chair.
# 1 0 so, we're not necessarily seeing a correlation with the data.
# 1 0 these amendments will allow the lanterman coalition 10% funding to
# 1 0 so, this bill actually to our attention from our attorney general who saw what happened with the gas leak.
# 1 0 <BILL_ID> enables healthcare providers in prisons and jails to learn from best practices used at state correctional facilities.
# 1 0 having served when the city of compton had its own police department.
# 1 0 i just want to thank you your consideration, and with that turn it over to our witnesses.
# 1 0 that puts california sometimes at odds or
# 1 0 cannella aye. gaines?
# 1 0 aye. >> aye, huff?
# 1 0 we will be hearing our first bill of the day, that's <BILL_ID>
# 1 0 all members photo wish ...this is to add-on as co-authors.
# 1 0 i just want to say that during spring break, i spent three days at california's largest state park which is
# 1 0 of time years is just going to be pastor with no actual language in it,
# 1 0 the courts to say if you don't go through these rehabilitative services then you will be charged with a felony, that's gone now.
# 1 0 with passenger carriers, with tour buses, the subject of this bill, they are, each carrier is inspected every 13 months.
# 1 0 pieces of the proposal that you would like us to focus on we're happy to jump to those as well.
# 1 0 children now, united ways of california, and of course cchi.
# 1 0 hi, thank you very much for allowing me to speak this afternoon.
# 1 0 it's in the first section that is the section that remains today.
# 1 0 campuses i understand opponents of this bill fill that these sexual
# 1 0 and i know for a lot of us we talked about how it's a tragedy, how we were sorry it happened,
# 1 0 i have with me today stacy preach a former california virtual academy educator and
# 1 0 mr. lackey, i don't know who's your daddy,
# 1 0 no. berryhill i had a no?
# 1 0 the following members were granted prior permission to speak on a german in memory.
# 1 0 mr. gordon, you're recognized.
# 1 0 so i have two witnesses who will self introduce and speak in support of <BILL_ID>
# 1 0 here. >> santiago.
# 1 0 all members vote who desire to vote.
# 1 0 it simply is a law that eliminates obsolete laws,
# 1 0 and with that, would ask for an aye vote.
# 1 0 and the secretary of the interior, secretary of commerce, state of california,
# 1 0 we're all well aware of the dangers of smoking and of the negative impact of secondhand exposure to smoke.
# 1 0 i ask for an aye vote on the amendments.
# 1 0 so we're both struggling the lack of terminology.
# 1 0 we need to make sure that these laws work well i also know as this moves through the process
# 1 0 comprehensive pcp that normalizes and addresses the gaps and
# 1 0 allowing bicycles the option of replacing their reflector with a more visible light will give them greater protection
# 1 0 and i realized at that time following the legislation that we did, that the country adopted,
# 1 0 ...you as the alleging that district have been negligent and that the victim had
# 1 0 are we getting a little ahead of things here with the connectivities?
# 1 0 aye. >> bigelow aye campos?
# 1 0 united arbon will increase it's payment to the revenue's sharing trust fund from two million to nine million.
# 1 0 which they don't do, so they shouldn't get repair money for it.
# 1 0 it doesn't have to be that way.
# 1 0 aye. >> aye, liu.
# 1 0 issuance of carry and concealed weapons, ccw permits.
# 1 0 on a couple things that the author and the floor manager have said, regarding <BILL_ID>
# 1 0 aye, vidak?
# 1 0 they operate it, and they open it up to the public when school is not in session.
# 1 0 that we'll have better results, and votes built.
# 1 0 increase access to calfresh and cal works for eligible working families.
# 1 0 big money.
# 1 0 the other property mouse.
# 1 0 and we look forward to continue working with the senator's staff on this, thank you very much.
# 1 0 it's critical we do everything possible to enhance turnouts so our government better reflects the will of the people.
# 1 0 aye. fuller?
# 1 0 aye. >> aye, huff?
# 1 0 ...health and wellness center with multiple sites throughout south los angeles a
# 1 0 moving now to file item 19.
# 1 0 ...is there any objection to substituting
# 1 0 and most of us in obstetrics and gynecology know, number one,
# 1 0 the senator just spoke to that issue, and i think that's very important.
# 1 0 the ability of a party to get unfairly, super-representing the chains review process
# 1 0 $600 million of that aforementioned $1.1 billion is proposed to fund the electrification of the cal-train corridor between san francisco and san jose.
# 1 0 mr. jones, i understand your mic was up as i was calling for the roll.
# 1 0 physical matter including digital images and video recordings i'm taking these
# 1 0 aye. >> aye, jackson.
# 1 0 the employer has a contract and is naturally going to go to that should there be an arbitration clause,
# 1 0 drug medical contracts, or hope to start offering services under the new dmc waiver.
# 1 0 madam chair, i would suggest that the senate position would be that we would certainly be interested in
# 1 0 i think we need to set the example for the state by changing our own rules here in the senate.
# 1 0 i represent the largest district in the state of california.
# 1 0 and we will be in room 112 across the hall.
